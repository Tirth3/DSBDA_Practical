# %%
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset('titanic')
df = pd.DataFrame(titanic)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
# Plot boxplot
sns.boxplot(data=titanic, x='sex', y='age', hue='survived')
plt.title("Age Distribution by Gender and Survival Status")
plt.xlabel("Gender")
plt.ylabel("Age")
# plt.legend(title='Survived', labels=['No', 'Yes'])  # Survival: 0 = No, 1 = Yes
plt.show()

# %% [markdown]
# # The box shows:
#
# - Median (center line)
#
# - IQR (box edges: 25th–75th percentile)
#
# - Whiskers (range, limited by 1.5x IQR)
#
# - Outliers (points outside whiskers)

# %% [markdown]
# # Observations
#
# ## 1. Survival by Gender:
# - Females had a significantly higher survival rate than males.
# - For males, the opposite is true — more men died than survived.
#
# ## 2. Age Distribution Patterns:
# - Children (younger ages) are more likely to appear in the survived group, especially among females.
# - Non-survivors (both males and females) have wider age ranges, but for males, many were in the 20–40 range.
#
# ## 4. Outliers and Spread:
# - Several older passengers (age > 60) survived, especially among females — these are seen as outliers above the whiskers.
# - The spread of ages (IQR) is slightly narrower for survivors than non-survivors, indicating more consistent age patterns among those who survived.
